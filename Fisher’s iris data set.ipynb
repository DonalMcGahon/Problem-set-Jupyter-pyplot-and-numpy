# %%
import numpy as np
csv = np.genfromtxt ('IRIS.csv', delimiter=",")
print (csv)
# Out:
# [[ 5.1         0.22222222  3.5         0.625       1.4         0.06779661
#    0.2         0.04166667         nan]
#  [ 4.9         0.16666667  3.          0.41666667  1.4         0.06779661
#    0.2         0.04166667         nan]
#  [ 4.7         0.11111111  3.2         0.5         1.3         0.05084746
#    0.2         0.04166667         nan]
#  [ 4.6         0.08333333  3.1         0.45833333  1.5         0.08474576
#    0.2         0.04166667         nan]
#  [ 5.          0.19444444  3.6         0.66666667  1.4         0.06779661
#    0.2         0.04166667         nan]
#  [ 5.4         0.30555556  3.9         0.79166667  1.7         0.11864407
#    0.4         0.125              nan]
#  [ 4.6         0.08333333  3.4         0.58333333  1.4         0.06779661
#    0.3         0.08333333         nan]
#  [ 5.          0.19444444  3.4         0.58333333  1.5         0.08474576
#    0.2         0.04166667         nan]
# ...
